# %%
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 21.1 MB/s  0:00:00 eta 0:00:01:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 19.0 MB/s  0:00:00 19.9 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]━━━━ 3/4 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 25.8 MB/s  0:00:007.3 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 23.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 24.4 MB/s  0:00:007.0 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib] 6/7 [matplotlib]ourpy]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("/home/gourav/Desktop/Weather-Visualization/data/weatherHistory.csv")

# %%
print(df.head())
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB
# None

# %%
print(df.describe())
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
print(df.columns)
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df["Formatted Date"] = pd.to_datetime(df["Formatted Date"], utc=True)

date = df["Formatted Date"]
temp = df["Temperature (C)"]

fig = plt.figure(figsize=(12,6))
ax = plt.axes()

ax.plot(date, temp, label="Temperature", color = 'Blue')
ax.set_title("Temperature over time Graph")
ax.set_xlabel("Date->")
ax.set_ylabel("Temperature->")
plt.show()

# %%
df['Month'] = df['Formatted Date'].dt.month

# %%
monthly_avg_temp = df.groupby('Month')['Temperature (C)'].mean()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
plt.plot(monthly_avg_temp.index, monthly_avg_temp.values, marker='o', linestyle='-', color='red')
plt.title("Monthly Average Temp")
plt.xlabel("Months")
plt.xticks(range(1,13))
plt.ylabel("Avg Temperature (C)")
plt.grid(True)
plt.show()

# %%
fig = plt.figure(figsize=(12, 6))
ax = plt.axes()
ax.plot(df['Temperature (C)'], df['Humidity'], color='teal', alpha=0.5)
plt.title("Humidity v/s Temperature")
plt.xlabel("Temperature (C)")
plt.ylabel("Humidity")
plt.grid(True)
plt.show()

# %%
df['Month']
# Out:
# 0        3
# 1        3
# 2        4
# 3        4
# 4        4
#         ..
# 96448    9
# 96449    9
# 96450    9
# 96451    9
# 96452    9
# Name: Month, Length: 96453, dtype: int32

# %%
plt.figure(figsize=(12,6))
df.boxplot(column='Temperature (C)', by='Month', grid=False)
plt.title("Monthly Temperature Distribution")
# plt.suptitle("") 
plt.ylabel("Temperature (C)")
plt.show()

# %%
print(df['Formatted Date'])
# Out:
# 0       2006-03-31 22:00:00+00:00
# 1       2006-03-31 23:00:00+00:00
# 2       2006-04-01 00:00:00+00:00
# 3       2006-04-01 01:00:00+00:00
# 4       2006-04-01 02:00:00+00:00
#                    ...
# 96448   2016-09-09 17:00:00+00:00
# 96449   2016-09-09 18:00:00+00:00
# 96450   2016-09-09 19:00:00+00:00
# 96451   2016-09-09 20:00:00+00:00
# 96452   2016-09-09 21:00:00+00:00
# Name: Formatted Date, Length: 96453, dtype: datetime64[ns, UTC]

# %%
df = df.dropna(subset=['Formatted Date', 'Temperature (C)'])

# %%
df['Year'] = df['Formatted Date'].dt.year

# %%
df['Day'] = df['Formatted Date'].dt.day

# %%
df['Date'] = df['Formatted Date'].dt.date

# %%
daily_temp = df.groupby('Date')['Temperature (C)'].mean()
plt.figure(figsize=(12,6))
plt.plot(daily_temp.index, daily_temp.values, color="blue", label="Daily Avg Temp (°C)")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.title("Daily Average Temperature Over Time")
plt.legend()
plt.show()

# %%
print(df['Apparent Temperature (C)'])
# Out:
# 0         7.388889
# 1         7.227778
# 2         9.377778
# 3         5.944444
# 4         6.977778
#            ...
# 96448    26.016667
# 96449    24.583333
# 96450    22.038889
# 96451    21.522222
# 96452    20.438889
# Name: Apparent Temperature (C), Length: 96453, dtype: float64

# %%
daily_avg = df.groupby('Date')[['Temperature (C)', 'Apparent Temperature (C)']].mean()

plt.figure(figsize=(12,6))
plt.plot(daily_avg.index, daily_avg['Temperature (C)'], label='Actual Temperature', linewidth=2.2, alpha=0.8, color = 'blue')
plt.plot(daily_avg.index, daily_avg['Apparent Temperature (C)'], label='Apparent Temperature',linewidth=2, linestyle="--", alpha=0.9, color='red')

plt.title("Daily Temperature v/s Apparent Temperature")
plt.xlabel("Date")
plt.ylabel("Temperature->")
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df['Temperature (C)'], bins=30, kde=True, color="green")
plt.title("Distribution of Daily Temperatures")
plt.show()

# %%
daily_humidity = df.groupby('Date')['Humidity'].mean()

plt.figure(figsize=(12,6))
sns.histplot(daily_humidity, bins=30, kde=True, color='skyblue')
plt.title("Daily Humidity")
plt.show()
